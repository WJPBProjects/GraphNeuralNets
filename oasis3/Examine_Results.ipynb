# %% [markdown]
# # Workbook to examine results and save ROC curves

# %%
# !hostname
# Out:
# texel05.doc.ic.ac.uk

# %%
from utils.results_interpreting_utils import examine, examine_1_type

# %%
img = 'Unbalanced_Alz_Preds.png'
run = "static_classification_results_binary_2"
subs = ["all_substructs", "hippocampi_only"]
subs_names = ["All substructures (15)", "Left & Right Hippocampi"]
types = ["PCA_unbalanced_preds_", "GCN_unbalanced_preds_", "Spline_unbalanced_preds_"]
examine(run, subs, subs_names, types, img)
# Out:
# all_substructs PCA_unbalanced_preds_
# Normalised average matrix
#  [[77.9 14.8]
#  [ 2.2  5.1]]
#
# Accuracy:  0.8293 ± 0.0170
#
# Balanced acc. :  0.7680 ± 0.0350
#
# Precision:  0.2565 ± 0.0306
#
# Recall:  0.6958 ± 0.0891
#
# F1:  0.3718 ± 0.0313
#
# Specificity:  0.3489 ± 0.0330
#
# MCC:  0.8401 ± 0.0245
#
# AUC:  0.8341 ± 0.0325
#
#
#
# all_substructs GCN_unbalanced_preds_
# Normalised average matrix
#  [[91.3  1.4]
#  [ 5.5  1.8]]
#
# Accuracy:  0.9316 ± 0.0114
#
# Balanced acc. :  0.6237 ± 0.0597
#
# Precision:  0.6309 ± 0.2032
#
# Recall:  0.2623 ± 0.1274
#
# F1:  0.3448 ± 0.1003
#
# Specificity:  0.3628 ± 0.0993
#
# MCC:  0.9851 ± 0.0112
#
# AUC:  0.8747 ± 0.0369
#
#
#
# all_substructs Spline_unbalanced_preds_
# Normalised average matrix
#  [[90.6  2.1]
#  [ 5.3  2. ]]
#
# Accuracy:  0.9264 ± 0.0107
#
# Balanced acc. :  0.6264 ± 0.0533
#
# Precision:  0.5299 ± 0.1155
#
# Recall:  0.2751 ± 0.1157
#
# F1:  0.3388 ± 0.1120
#
# Specificity:  0.3340 ± 0.0906
#
# ...

# %%
img = 'Balanced_Alz_Preds.png'
run = "static_classification_results_binary_2"
subs = ["all_substructs", "hippocampi_only"]
subs_names = ["All substructures (15)", "Left & Right Hippocampi"]
types = ["PCA_preds_", "GCN_preds_", "Spline_preds_"]
examine(run, subs, subs_names, types, img)
# Out:
# all_substructs PCA_preds_
# Normalised average matrix
#  [[67.9 24.8]
#  [ 1.6  5.7]]
#
# Accuracy:  0.7362 ± 0.0134
#
# Balanced acc. :  0.7615 ± 0.0327
#
# Precision:  0.1879 ± 0.0141
#
# Recall:  0.7908 ± 0.0831
#
# F1:  0.3028 ± 0.0198
#
# Specificity:  0.2941 ± 0.0284
#
# MCC:  0.7322 ± 0.0202
#
# AUC:  0.8425 ± 0.0363
#
#
#
# all_substructs GCN_preds_
# Normalised average matrix
#  [[78.6 14.1]
#  [ 1.6  5.7]]
#
# Accuracy:  0.8437 ± 0.0314
#
# Balanced acc. :  0.8187 ± 0.0331
#
# Precision:  0.2987 ± 0.0682
#
# Recall:  0.7892 ± 0.0703
#
# F1:  0.4286 ± 0.0669
#
# Specificity:  0.4201 ± 0.0632
#
# MCC:  0.8482 ± 0.0357
#
# AUC:  0.8640 ± 0.0380
#
#
#
# all_substructs Spline_preds_
# Normalised average matrix
#  [[90.3  2.4]
#  [ 5.6  1.7]]
#
# Accuracy:  0.9201 ± 0.0162
#
# Balanced acc. :  0.6032 ± 0.0448
#
# Precision:  0.4704 ± 0.1555
#
# Recall:  0.2325 ± 0.0971
#
# F1:  0.2896 ± 0.0995
#
# Specificity:  0.2799 ± 0.0921
#
# MCC:  0.9739 ± 0.0179
#
# AUC:  0.8428 ± 0.0487
# ...
